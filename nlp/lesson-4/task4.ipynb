# %%
import re
import nltk
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from nltk import tokenize as tknz
from nltk.corpus import stopwords

from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet

from natasha import Doc, MorphVocab, Segmenter, NewsEmbedding, NewsMorphTagger


nltk.download('wordnet')

# %%
class TextProcessor:
    
    def __init__(self,message=None,verbose=False):
        self._message= message
        self._verbose=verbose
        self.tokens=[]

    def set_message(self,msg):
        self._message = msg;
        if self._verbose: print ("  --> The message was set {}".format(self._message))
        return self

    def get_message(self):
        return self._message

    def remove_email_word(self,replace=" "):
        xtr = re.sub(pattern="@[\w]*",repl=replace,string=self._message)
        if self._verbose: print("  --> The @word was removed {} {} ".format(xtr,self._message))
        return self.set_message(msg=xtr)
    
    def remove_punctuation(self,replace=" "):
        xtr = re.sub(pattern=r'[^\w\s]',repl=replace,string=self._message)
        if self._verbose: print("  --> Removing punctuation: {} {}".format(xtr,self._message))
        return self.set_message(msg=xtr)

    def remove_special_sym(self,replace=" "):
        xtr = re.sub(pattern=r'[^a-zA-Z0-9]',repl=replace,string=self._message)
        if self._verbose: print ("  --> Removing special symbols: {} {}".format(xtr,self._message))
        return self.set_message(msg=xtr)
    
    def remove_numbers(self,replace=" "):
        xtr = re.sub(pattern=r'[^a-zA-Z]',repl=replace,string=self._message)
        if self._verbose: print("  --> Removing all numbers: {} {}".format(xtr,self._message))
        return self.set_message(msg=xtr)

    def to_lower (self ):
        xtr = self._message.lower();
        if self._verbose: print ("  --> Making to lower case: {} {}".format(xtr,self._message))
        return self.set_message(msg=xtr)

    def replace_by_dicts (self,dictionary: dict):
        for key in dictionary:
            xtr = self._message.replace(key,dictionary[key])
            #re.sub(pattern=key,repl=dictionary[key],string=self._message)
            if self._verbose:
                print ("  --> Replacing: {}->{} Result: before: {} after: {}".format(key,dictionary[key],self._message,xtr))
            self.set_message(msg=xtr)
        return self

    def escape_single_symbol_words (self):
        xtr=" ".join([word for word in self._message.split() if len(word)>1])
        if self._verbose:
            print ("  --> Escaping single symbol words: {} {}".format(xtr,self._message))
        return self.set_message(msg=xtr)

    def make_tokenization(self,tokenizer):
        self.tokens=tokenizer(self._message)
        if self._verbose:
            print ("  --> custom tokenizer was completed: {}".format(self.tokens))
        return self

    def nltk_word_tokenize(self):
        self.tokens=tknz.word_tokenize(self._message)
        if self._verbose:
            print ("  --> nltk.tokenize.word_tokenize was completed: {}".format(self.tokens))
        return self

    def nltk_word_punc_tokenize(self):
        self.tokens = tknz.wordpunct_tokenize(self._message)
        if self._verbose:
            print ("  --> nltk.tokenize.wordpunct_tokenize was completed: {}".format(self.tokens))
        return self

    def nltk_tok_tok_tokenizer(self):
        self.tokens = tknz.ToktokTokenizer().tokenize(self._message)
        if self._verbose:
            print ("  --> nltk.tokenize.ToktokTokenizer().tokenize was completed: {}".format(self.tokens))
        return self
        
    def nltk_tweet_tokenizer(self):
        self.tokens = tknz.TweetTokenizer().tokenize(self._message)
        if self._verbose:
            print ("  --> nltk.tokenize.TweetTokenizer().tokenize was completed: {}".format(self.tokens))
        return self

    def nltk_with_regexp_tokenizer (self,regexp):
        self.tokens = tknz.RegexpTokenizer(regexp).tokenize(self._message)
        if self._verbose:
            print ("  --> nltk.tokenize.RegexpTokenizer({}).tokenize was completed: {}".format(regexp,self.tokens))
        return self

    def nltk_sentence_tokenizer (self):
        self.tokens = nltk.sent_tokenize(self._message)
        if self._verbose:
            print ("  --> nltk.sent_tokenize() was completed: {}".format(self.tokens))
        return self

    def remove_stopwords_from_tokens (self,lang=None,is_new=True):
        if lang is None:
            sw = set(stopwords.words("english"))
        else :
            sw = set(stopwords.words(lang))
        tks = [token for token in self.tokens if token not in sw]
        if is_new:
            self.tokens_without_stops = tks
        else :
            self.tokens = tks
        return self

    def stemme_tokens (self,stemmer=None,is_new=True):
        if stemmer is None:
            stemmer = PorterStemmer()
        xtr = [stemmer.stem(token) for token in self.tokens]
        if is_new :
            self.stem_tokens = xtr
        else :
            self.tokens = xtr
        return self

    def lematize_tokens (self,lematizer=None,is_new=True):
        if lematizer is None:
            lematizer = WordNetLemmatizer()
        xtr = [lematizer.lemmatize(token) for token in self.tokens]
        if is_new:
            self.lem_tokens = xtr
        else :
            self.tokens = xtr
        return self

# %%
import pandas as pd

file_path_1 = "/home/alex/dev/AiLearning/DataSetStore/twitter_messages_2/negative.csv"
df1 = pd.read_csv(file_path_1,header=None,on_bad_lines='skip',sep=";")

file_path_2 = "/home/alex/dev/AiLearning/DataSetStore/twitter_messages_2/positive.csv"
df2 = pd.read_csv(file_path_2,header=None,on_bad_lines='skip',sep=";")

df = df1._append(df2)
df.head()
df_copy = df.copy()[0:300]

# %%
def make_natasha_tokens(text,
                        morphology_filter_set=None,
                        token_length_limit=None,
                        empty_token="empty",
                        verbose=False):
    segmenter = Segmenter()
    morph_tagger = NewsMorphTagger(NewsEmbedding())
    morph_vocab = MorphVocab()
    
    doc = Doc(text)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)

    selected_tokens=[]
    for token in doc.tokens:
        token.lemmatize(morph_vocab)
        if verbose:
            print (" >> Input {} ".format(token))
        new_token = None
        if morphology_filter_set is None:
            new_token = token.lemma
        else:
            if token.pos in morphology_filter_set:
                new_token = token.lemma
        if new_token is not None and token_length_limit is not None:
            if len(new_token)<token_length_limit:
                new_token = None
        if new_token is not None:
            selected_tokens.append(new_token)
        if verbose:
            print (" >> Output {} ".format(new_token))
    if len(selected_tokens)==0 :
        selected_tokens.append(empty_token)
    return selected_tokens

make_natasha_tokens(text="Желаю хорошего полёта и удачной посадки,я буду",morphology_filter_set=('NOUN','VERB'), token_length_limit=3,verbose=True)

# %%
def process(txt: str,verbose=False):
    return TextProcessor(verbose=verbose)\
    .set_message(msg=txt)\
    .remove_email_word()\
    .remove_punctuation()\
    .to_lower()\
    .escape_single_symbol_words()\
    .remove_stopwords_from_tokens(lang='russian',is_new=False)\
    .make_tokenization(tokenizer=lambda txt: make_natasha_tokens(text=txt,morphology_filter_set=('NOUN','VERB'),token_length_limit=3))\
    .tokens
    

process(txt="Желаю хорошего полёта и удачной посадки,я буду",verbose=True)

# %%
df_copy['tokens'] = df_copy[3].apply(lambda txt: process(txt=txt,verbose=False))
df_copy.head()
# Out:
#   --> The message was set на работе был полный пиддес :| и так каждое закрытие месяца, я же свихнусь так D:
#   --> The @word was removed на работе был полный пиддес :| и так каждое закрытие месяца, я же свихнусь так D: на работе был полный пиддес :| и так каждое закрытие месяца, я же свихнусь так D:
#   --> The message was set на работе был полный пиддес :| и так каждое закрытие месяца, я же свихнусь так D:
#   --> Removing punctuation: на работе был полный пиддес    и так каждое закрытие месяца  я же свихнусь так D  на работе был полный пиддес :| и так каждое закрытие месяца, я же свихнусь так D:
#   --> The message was set на работе был полный пиддес    и так каждое закрытие месяца  я же свихнусь так D
#   --> Making to lower case: на работе был полный пиддес    и так каждое закрытие месяца  я же свихнусь так d  на работе был полный пиддес    и так каждое закрытие месяца  я же свихнусь так D
#   --> The message was set на работе был полный пиддес    и так каждое закрытие месяца  я же свихнусь так d
#   --> Escaping single symbol words: на работе был полный пиддес так каждое закрытие месяца же свихнусь так на работе был полный пиддес    и так каждое закрытие месяца  я же свихнусь так d
#   --> The message was set на работе был полный пиддес так каждое закрытие месяца же свихнусь так
#   --> custom tokenizer was completed: ['работа', 'пиддес', 'закрытие', 'месяц', 'свихнуться']
#   --> The message was set Коллеги сидят рубятся в Urban terror, а я из-за долбанной винды не могу :(
#   --> The @word was removed Коллеги сидят рубятся в Urban terror, а я из-за долбанной винды не могу :( Коллеги сидят рубятся в Urban terror, а я из-за долбанной винды не могу :(
#   --> The message was set Коллеги сидят рубятся в Urban terror, а я из-за долбанной винды не могу :(
#   --> Removing punctuation: Коллеги сидят рубятся в Urban terror  а я из за долбанной винды не могу    Коллеги сидят рубятся в Urban terror, а я из-за долбанной винды не могу :(
#   --> The message was set Коллеги сидят рубятся в Urban terror  а я из за долбанной винды не могу
#   --> Making to lower case: коллеги сидят рубятся в urban terror  а я из за долбанной винды не могу    Коллеги сидят рубятся в Urban terror  а я из за долбанной винды не могу
#   --> The message was set коллеги сидят рубятся в urban terror  а я из за долбанной винды не могу
#   --> Escaping single symbol words: коллеги сидят рубятся urban terror из за долбанной винды не могу коллеги сидят рубятся в urban terror  а я из за долбанной винды не могу
#   --> The message was set коллеги сидят рубятся urban terror из за долбанной винды не могу
#   --> custom tokenizer was completed: ['коллега', 'сидеть', 'рубятся', 'винд', 'мочь']
#   --> The message was set @elina_4post как говорят обещаного три года ждут...((
#   --> The @word was removed   как говорят обещаного три года ждут...(( @elina_4post как говорят обещаного три года ждут...((
#   --> The message was set   как говорят обещаного три года ждут...((
#   --> Removing punctuation:   как говорят обещаного три года ждут        как говорят обещаного три года ждут...((
#   --> The message was set   как говорят обещаного три года ждут
#   --> Making to lower case:   как говорят обещаного три года ждут        как говорят обещаного три года ждут
#   --> The message was set   как говорят обещаного три года ждут
#   --> Escaping single symbol words: как говорят обещаного три года ждут   как говорят обещаного три года ждут
#   --> The message was set как говорят обещаного три года ждут
#   --> custom tokenizer was completed: ['говорить', 'обещаного', 'год', 'ждать']
#   --> The message was set Желаю хорошего полёта и удачной посадки,я буду очень сильно скучать( http://t.co/jCLNzVNv3S
#   --> The @word was removed Желаю хорошего полёта и удачной посадки,я буду очень сильно скучать( http://t.co/jCLNzVNv3S Желаю хорошего полёта и удачной посадки,я буду очень сильно скучать( http://t.co/jCLNzVNv3S
#   --> The message was set Желаю хорошего полёта и удачной посадки,я буду очень сильно скучать( http://t.co/jCLNzVNv3S
#   --> Removing punctuation: Желаю хорошего полёта и удачной посадки я буду очень сильно скучать  http   t co jCLNzVNv3S Желаю хорошего полёта и удачной посадки,я буду очень сильно скучать( http://t.co/jCLNzVNv3S
#   --> The message was set Желаю хорошего полёта и удачной посадки я буду очень сильно скучать  http   t co jCLNzVNv3S
#   --> Making to lower case: желаю хорошего полёта и удачной посадки я буду очень сильно скучать  http   t co jclnzvnv3s Желаю хорошего полёта и удачной посадки я буду очень сильно скучать  http   t co jCLNzVNv3S
#   --> The message was set желаю хорошего полёта и удачной посадки я буду очень сильно скучать  http   t co jclnzvnv3s
#   --> Escaping single symbol words: желаю хорошего полёта удачной посадки буду очень сильно скучать http co jclnzvnv3s желаю хорошего полёта и удачной посадки я буду очень сильно скучать  http   t co jclnzvnv3s
#   --> The message was set желаю хорошего полёта удачной посадки буду очень сильно скучать http co jclnzvnv3s
#   --> custom tokenizer was completed: ['желать', 'полет', 'посадка', 'скучать']
#   --> The message was set Обновил за каким-то лешим surf, теперь не работает простоплеер :(
#   --> The @word was removed Обновил за каким-то лешим surf, теперь не работает простоплеер :( Обновил за каким-то лешим surf, теперь не работает простоплеер :(
#   --> The message was set Обновил за каким-то лешим surf, теперь не работает простоплеер :(
#   --> Removing punctuation: Обновил за каким то лешим surf  теперь не работает простоплеер    Обновил за каким-то лешим surf, теперь не работает простоплеер :(
#   --> The message was set Обновил за каким то лешим surf  теперь не работает простоплеер
#   --> Making to lower case: обновил за каким то лешим surf  теперь не работает простоплеер    Обновил за каким то лешим surf  теперь не работает простоплеер
#   --> The message was set обновил за каким то лешим surf  теперь не работает простоплеер
#   --> Escaping single symbol words: обновил за каким то лешим surf теперь не работает простоплеер обновил за каким то лешим surf  теперь не работает простоплеер
#   --> The message was set обновил за каким то лешим surf теперь не работает простоплеер
#   --> custom tokenizer was completed: ['обновить', 'леший', 'работать', 'простоплеер']
#   --> The message was set Котёнка вчера носик разбила, плакала и расстраивалась :(
#   --> The @word was removed Котёнка вчера носик разбила, плакала и расстраивалась :( Котёнка вчера носик разбила, плакала и расстраивалась :(
#   --> The message was set Котёнка вчера носик разбила, плакала и расстраивалась :(
#   --> Removing punctuation: Котёнка вчера носик разбила  плакала и расстраивалась    Котёнка вчера носик разбила, плакала и расстраивалась :(
#   --> The message was set Котёнка вчера носик разбила  плакала и расстраивалась
#   --> Making to lower case: котёнка вчера носик разбила  плакала и расстраивалась    Котёнка вчера носик разбила  плакала и расстраивалась
#   --> The message was set котёнка вчера носик разбила  плакала и расстраивалась
#   --> Escaping single symbol words: котёнка вчера носик разбила плакала расстраивалась котёнка вчера носик разбила  плакала и расстраивалась
#   --> The message was set котёнка вчера носик разбила плакала расстраивалась
#   --> custom tokenizer was completed: ['котенок', 'носик', 'разбить', 'плакать']
#   --> The message was set @juliamayko @O_nika55 @and_Possum Зашли, а то он опять затихарился, я прямо физически страдаю, когда он долго молчит!(((
#   --> The @word was removed       Зашли, а то он опять затихарился, я прямо физически страдаю, когда он долго молчит!((( @juliamayko @O_nika55 @and_Possum Зашли, а то он опять затихарился, я прямо физически страдаю, когда он долго молчит!(((
#   --> The message was set       Зашли, а то он опять затихарился, я прямо физически страдаю, когда он долго молчит!(((
#   --> Removing punctuation:       Зашли  а то он опять затихарился  я прямо физически страдаю  когда он долго молчит           Зашли, а то он опять затихарился, я прямо физически страдаю, когда он долго молчит!(((
#   --> The message was set       Зашли  а то он опять затихарился  я прямо физически страдаю  когда он долго молчит
#   --> Making to lower case:       зашли  а то он опять затихарился  я прямо физически страдаю  когда он долго молчит           Зашли  а то он опять затихарился  я прямо физически страдаю  когда он долго молчит
#   --> The message was set       зашли  а то он опять затихарился  я прямо физически страдаю  когда он долго молчит
#   --> Escaping single symbol words: зашли то он опять затихарился прямо физически страдаю когда он долго молчит       зашли  а то он опять затихарился  я прямо физически страдаю  когда он долго молчит
#   --> The message was set зашли то он опять затихарился прямо физически страдаю когда он долго молчит
#   --> custom tokenizer was completed: ['зайти', 'затихариться', 'страдать', 'молчать']
#   --> The message was set а вообще я не болею -  я не выздоравливаю :(
#   --> The @word was removed а вообще я не болею -  я не выздоравливаю :( а вообще я не болею -  я не выздоравливаю :(
#   --> The message was set а вообще я не болею -  я не выздоравливаю :(
#   --> Removing punctuation: а вообще я не болею    я не выздоравливаю    а вообще я не болею -  я не выздоравливаю :(
#   --> The message was set а вообще я не болею    я не выздоравливаю
#   --> Making to lower case: а вообще я не болею    я не выздоравливаю    а вообще я не болею    я не выздоравливаю
#   --> The message was set а вообще я не болею    я не выздоравливаю
#   --> Escaping single symbol words: вообще не болею не выздоравливаю а вообще я не болею    я не выздоравливаю
#   --> The message was set вообще не болею не выздоравливаю
#   --> custom tokenizer was completed: ['болеть', 'выздоравливать']
#   --> The message was set я микрофраза :( учимся срать кирпичами в режиме &amp;quot;нон-стоп&amp;quot; @niwoqisipapy
#   --> The @word was removed я микрофраза :( учимся срать кирпичами в режиме &amp;quot;нон-стоп&amp;quot;   я микрофраза :( учимся срать кирпичами в режиме &amp;quot;нон-стоп&amp;quot; @niwoqisipapy
#   --> The message was set я микрофраза :( учимся срать кирпичами в режиме &amp;quot;нон-стоп&amp;quot;
#   --> Removing punctuation: я микрофраза    учимся срать кирпичами в режиме  amp quot нон стоп amp quot    я микрофраза :( учимся срать кирпичами в режиме &amp;quot;нон-стоп&amp;quot;
#   --> The message was set я микрофраза    учимся срать кирпичами в режиме  amp quot нон стоп amp quot
#   --> Making to lower case: я микрофраза    учимся срать кирпичами в режиме  amp quot нон стоп amp quot    я микрофраза    учимся срать кирпичами в режиме  amp quot нон стоп amp quot
#   --> The message was set я микрофраза    учимся срать кирпичами в режиме  amp quot нон стоп amp quot
#   --> Escaping single symbol words: микрофраза учимся срать кирпичами режиме amp quot нон стоп amp quot я микрофраза    учимся срать кирпичами в режиме  amp quot нон стоп amp quot
#   --> The message was set микрофраза учимся срать кирпичами режиме amp quot нон стоп amp quot
#   --> custom tokenizer was completed: ['микрофраза', 'учиться', 'режим', 'стоп']
#   --> The message was set я хочу с тобой помириться , но сука я гордая и никогда этого не сделаю! (((
#   --> The @word was removed я хочу с тобой помириться , но сука я гордая и никогда этого не сделаю! ((( я хочу с тобой помириться , но сука я гордая и никогда этого не сделаю! (((
#   --> The message was set я хочу с тобой помириться , но сука я гордая и никогда этого не сделаю! (((
#   --> Removing punctuation: я хочу с тобой помириться   но сука я гордая и никогда этого не сделаю      я хочу с тобой помириться , но сука я гордая и никогда этого не сделаю! (((
#   --> The message was set я хочу с тобой помириться   но сука я гордая и никогда этого не сделаю
#   --> Making to lower case: я хочу с тобой помириться   но сука я гордая и никогда этого не сделаю      я хочу с тобой помириться   но сука я гордая и никогда этого не сделаю
#   --> The message was set я хочу с тобой помириться   но сука я гордая и никогда этого не сделаю
#   --> Escaping single symbol words: хочу тобой помириться но сука гордая никогда этого не сделаю я хочу с тобой помириться   но сука я гордая и никогда этого не сделаю
#   --> The message was set хочу тобой помириться но сука гордая никогда этого не сделаю
#   --> custom tokenizer was completed: ['хотеть', 'помириться', 'сделать']
#   --> The message was set @DNO_OKEANA_A3A3 @MOE_MOPE_A3A3 тебя ебет какие у меня фотки.я про твои молчу.и вообще ты хоть знаешь как ТП то выглядят...
#   --> The @word was removed     тебя ебет какие у меня фотки.я про твои молчу.и вообще ты хоть знаешь как ТП то выглядят... @DNO_OKEANA_A3A3 @MOE_MOPE_A3A3 тебя ебет какие у меня фотки.я про твои молчу.и вообще ты хоть знаешь как ТП то выглядят...
#   --> The message was set     тебя ебет какие у меня фотки.я про твои молчу.и вообще ты хоть знаешь как ТП то выглядят...
#   --> Removing punctuation:     тебя ебет какие у меня фотки я про твои молчу и вообще ты хоть знаешь как ТП то выглядят        тебя ебет какие у меня фотки.я про твои молчу.и вообще ты хоть знаешь как ТП то выглядят...
#   --> The message was set     тебя ебет какие у меня фотки я про твои молчу и вообще ты хоть знаешь как ТП то выглядят
#   --> Making to lower case:     тебя ебет какие у меня фотки я про твои молчу и вообще ты хоть знаешь как тп то выглядят        тебя ебет какие у меня фотки я про твои молчу и вообще ты хоть знаешь как ТП то выглядят
#   --> The message was set     тебя ебет какие у меня фотки я про твои молчу и вообще ты хоть знаешь как тп то выглядят
#   --> Escaping single symbol words: тебя ебет какие меня фотки про твои молчу вообще ты хоть знаешь как тп то выглядят     тебя ебет какие у меня фотки я про твои молчу и вообще ты хоть знаешь как тп то выглядят
#   --> The message was set тебя ебет какие меня фотки про твои молчу вообще ты хоть знаешь как тп то выглядят
#   --> custom tokenizer was completed: ['фотка', 'молчу', 'знать', 'выглядеть']
#   --> The message was set Блин начали сниться сны( Не когда почти не снились ! А теперь можно сказать каждый день такое ! Мне это не нравиться ((((((((((
#   --> The @word was removed Блин начали сниться сны( Не когда почти не снились ! А теперь можно сказать каждый день такое ! Мне это не нравиться (((((((((( Блин начали сниться сны( Не когда почти не снились ! А теперь можно сказать каждый день такое ! Мне это не нравиться ((((((((((
#   --> The message was set Блин начали сниться сны( Не когда почти не снились ! А теперь можно сказать каждый день такое ! Мне это не нравиться ((((((((((
#   --> Removing punctuation: Блин начали сниться сны  Не когда почти не снились   А теперь можно сказать каждый день такое   Мне это не нравиться            Блин начали сниться сны( Не когда почти не снились ! А теперь можно сказать каждый день такое ! Мне это не нравиться ((((((((((
#   --> The message was set Блин начали сниться сны  Не когда почти не снились   А теперь можно сказать каждый день такое   Мне это не нравиться
#   --> Making to lower case: блин начали сниться сны  не когда почти не снились   а теперь можно сказать каждый день такое   мне это не нравиться            Блин начали сниться сны  Не когда почти не снились   А теперь можно сказать каждый день такое   Мне это не нравиться
#   --> The message was set блин начали сниться сны  не когда почти не снились   а теперь можно сказать каждый день такое   мне это не нравиться
#   --> Escaping single symbol words: блин начали сниться сны не когда почти не снились теперь можно сказать каждый день такое мне это не нравиться блин начали сниться сны  не когда почти не снились   а теперь можно сказать каждый день такое   мне это не нравиться
#   --> The message was set блин начали сниться сны не когда почти не снились теперь можно сказать каждый день такое мне это не нравиться
#   --> custom tokenizer was completed: ['блин', 'начать', 'сниться', 'сон', 'сниться', 'сказать', 'день', 'нравиться']
#   --> The message was set @realVold На твоем месте, я бы сначала телек купил бы(
#   --> The @word was removed   На твоем месте, я бы сначала телек купил бы( @realVold На твоем месте, я бы сначала телек купил бы(
#   --> The message was set   На твоем месте, я бы сначала телек купил бы(
#   --> Removing punctuation:   На твоем месте  я бы сначала телек купил бы    На твоем месте, я бы сначала телек купил бы(
#   --> The message was set   На твоем месте  я бы сначала телек купил бы
#   --> Making to lower case:   на твоем месте  я бы сначала телек купил бы    На твоем месте  я бы сначала телек купил бы
#   --> The message was set   на твоем месте  я бы сначала телек купил бы
#   --> Escaping single symbol words: на твоем месте бы сначала телек купил бы   на твоем месте  я бы сначала телек купил бы
#   --> The message was set на твоем месте бы сначала телек купил бы
#   --> custom tokenizer was completed: ['место', 'телек', 'купить']
#   --> The message was set @faraonbgr111 плохо боишься значит(( ты где? В мск бгр?
#   --> The @word was removed   плохо боишься значит(( ты где? В мск бгр? @faraonbgr111 плохо боишься значит(( ты где? В мск бгр?
#   --> The message was set   плохо боишься значит(( ты где? В мск бгр?
#   --> Removing punctuation:   плохо боишься значит   ты где  В мск бгр    плохо боишься значит(( ты где? В мск бгр?
#   --> The message was set   плохо боишься значит   ты где  В мск бгр
#   --> Making to lower case:   плохо боишься значит   ты где  в мск бгр    плохо боишься значит   ты где  В мск бгр
#   --> The message was set   плохо боишься значит   ты где  в мск бгр
#   --> Escaping single symbol words: плохо боишься значит ты где мск бгр   плохо боишься значит   ты где  в мск бгр
#   --> The message was set плохо боишься значит ты где мск бгр
#   --> custom tokenizer was completed: ['бояться', 'бгр']
#   --> The message was set А я хотела... электромобиль =(
# http://t.co/vgs9JeUPHz
#   --> The @word was removed А я хотела... электромобиль =(
# http://t.co/vgs9JeUPHz А я хотела... электромобиль =(
# http://t.co/vgs9JeUPHz
#   --> The message was set А я хотела... электромобиль =(
# http://t.co/vgs9JeUPHz
#   --> Removing punctuation: А я хотела    электромобиль
# http   t co vgs9JeUPHz А я хотела... электромобиль =(
# http://t.co/vgs9JeUPHz
#   --> The message was set А я хотела    электромобиль
# http   t co vgs9JeUPHz
#   --> Making to lower case: а я хотела    электромобиль
# http   t co vgs9jeuphz А я хотела    электромобиль
# http   t co vgs9JeUPHz
#   --> The message was set а я хотела    электромобиль
# http   t co vgs9jeuphz
#   --> Escaping single symbol words: хотела электромобиль http co vgs9jeuphz а я хотела    электромобиль
# http   t co vgs9jeuphz
#   --> The message was set хотела электромобиль http co vgs9jeuphz
#   --> custom tokenizer was completed: ['хотеть', 'электромобиль']
#   --> The message was set Скоро увижу твои зеленые глаза в последний раз(((
#   --> The @word was removed Скоро увижу твои зеленые глаза в последний раз((( Скоро увижу твои зеленые глаза в последний раз(((
#   --> The message was set Скоро увижу твои зеленые глаза в последний раз(((
#   --> Removing punctuation: Скоро увижу твои зеленые глаза в последний раз    Скоро увижу твои зеленые глаза в последний раз(((
#   --> The message was set Скоро увижу твои зеленые глаза в последний раз
#   --> Making to lower case: скоро увижу твои зеленые глаза в последний раз    Скоро увижу твои зеленые глаза в последний раз
#   --> The message was set скоро увижу твои зеленые глаза в последний раз
#   --> Escaping single symbol words: скоро увижу твои зеленые глаза последний раз скоро увижу твои зеленые глаза в последний раз
#   --> The message was set скоро увижу твои зеленые глаза последний раз
#   --> custom tokenizer was completed: ['увидеть', 'глаз', 'раз']
#   --> The message was set Вот это да, докатился,по-оранжевел патриот! Чо деется? :(( RT @SapelSV: #Бабки объединят #КПРФ и Навального? http://t.co/kyJk4A79kv
#   --> The @word was removed Вот это да, докатился,по-оранжевел патриот! Чо деется? :(( RT  : #Бабки объединят #КПРФ и Навального? http://t.co/kyJk4A79kv Вот это да, докатился,по-оранжевел патриот! Чо деется? :(( RT @SapelSV: #Бабки объединят #КПРФ и Навального? http://t.co/kyJk4A79kv
#   --> The message was set Вот это да, докатился,по-оранжевел патриот! Чо деется? :(( RT  : #Бабки объединят #КПРФ и Навального? http://t.co/kyJk4A79kv
#   --> Removing punctuation: Вот это да  докатился по оранжевел патриот  Чо деется      RT     Бабки объединят  КПРФ и Навального  http   t co kyJk4A79kv Вот это да, докатился,по-оранжевел патриот! Чо деется? :(( RT  : #Бабки объединят #КПРФ и Навального? http://t.co/kyJk4A79kv
#   --> The message was set Вот это да  докатился по оранжевел патриот  Чо деется      RT     Бабки объединят  КПРФ и Навального  http   t co kyJk4A79kv
#   --> Making to lower case: вот это да  докатился по оранжевел патриот  чо деется      rt     бабки объединят  кпрф и навального  http   t co kyjk4a79kv Вот это да  докатился по оранжевел патриот  Чо деется      RT     Бабки объединят  КПРФ и Навального  http   t co kyJk4A79kv
#   --> The message was set вот это да  докатился по оранжевел патриот  чо деется      rt     бабки объединят  кпрф и навального  http   t co kyjk4a79kv
#   --> Escaping single symbol words: вот это да докатился по оранжевел патриот чо деется rt бабки объединят кпрф навального http co kyjk4a79kv вот это да  докатился по оранжевел патриот  чо деется      rt     бабки объединят  кпрф и навального  http   t co kyjk4a79kv
#   --> The message was set вот это да докатился по оранжевел патриот чо деется rt бабки объединят кпрф навального http co kyjk4a79kv
#   --> custom tokenizer was completed: ['докатиться', 'оранжевел', 'патриот', 'что', 'деяться', 'бабка', 'объединить', 'кпрф', 'навальный']
#   --> The message was set Ну уже 12:25 ночииии:(((( а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> The @word was removed Ну уже 12:25 ночииии:(((( а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп Ну уже 12:25 ночииии:(((( а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> The message was set Ну уже 12:25 ночииии:(((( а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> Removing punctuation: Ну уже 12 25 ночииии      а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп Ну уже 12:25 ночииии:(((( а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> The message was set Ну уже 12 25 ночииии      а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> Making to lower case: ну уже 12 25 ночииии      а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп Ну уже 12 25 ночииии      а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> The message was set ну уже 12 25 ночииии      а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> Escaping single symbol words: ну уже 12 25 ночииии ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп ну уже 12 25 ночииии      а я ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> The message was set ну уже 12 25 ночииии ничего не сделалаллалалалалалалвцмдэмппдпктцдкиицкп
#   --> custom tokenizer was completed: ['ночииия', 'сделалаллалалалалалалвцмдэмппдпктцдкиицкп']
#   --> The message was set @190299der я очень рада,но ты им разобьешь сердца:(
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#
#   --> The @word was removed   я очень рада,но ты им разобьешь сердца:(
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#  @190299der я очень рада,но ты им разобьешь сердца:(
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#
#   --> The message was set   я очень рада,но ты им разобьешь сердца:(
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#
#   --> Removing punctuation:   я очень рада но ты им разобьешь сердца
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#    я очень рада,но ты им разобьешь сердца:(
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#
#   --> The message was set   я очень рада но ты им разобьешь сердца
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#
#   --> Making to lower case:   я очень рада но ты им разобьешь сердца
# мне их  жалко епт
# мне оч жалко влада
# а всех остальных нет
#    я очень рада но ты им разобьешь сердца
# Мне их  жалко епт
# мне оч жалко Влада
# А всех остальных нет
#
#   --> The message was set   я очень рада но ты им разобьешь сердца
# мне их  жалко епт
# мне оч жалко влада
# а всех остальных нет
#
#   --> Escaping single symbol words: очень рада но ты им разобьешь сердца мне их жалко епт мне оч жалко влада всех остальных нет   я очень рада но ты им разобьешь сердца
# мне их  жалко епт
# мне оч жалко влада
# а всех остальных нет
#
#   --> The message was set очень рада но ты им разобьешь сердца мне их жалко епт мне оч жалко влада всех остальных нет
#   --> custom tokenizer was completed: ['разобьешь', 'сердце', 'епт', 'влад', 'нет']
#   --> The message was set Сегодня какой-то нехороший день у меня :-( Телефон наушники не опознает, у блога как-то умудрился шаблон сломать, да еще
#   --> The @word was removed Сегодня какой-то нехороший день у меня :-( Телефон наушники не опознает, у блога как-то умудрился шаблон сломать, да еще Сегодня какой-то нехороший день у меня :-( Телефон наушники не опознает, у блога как-то умудрился шаблон сломать, да еще
#   --> The message was set Сегодня какой-то нехороший день у меня :-( Телефон наушники не опознает, у блога как-то умудрился шаблон сломать, да еще
#   --> Removing punctuation: Сегодня какой то нехороший день у меня     Телефон наушники не опознает  у блога как то умудрился шаблон сломать  да еще Сегодня какой-то нехороший день у меня :-( Телефон наушники не опознает, у блога как-то умудрился шаблон сломать, да еще
#   --> The message was set Сегодня какой то нехороший день у меня     Телефон наушники не опознает  у блога как то умудрился шаблон сломать  да еще
#   --> Making to lower case: сегодня какой то нехороший день у меня     телефон наушники не опознает  у блога как то умудрился шаблон сломать  да еще Сегодня какой то нехороший день у меня     Телефон наушники не опознает  у блога как то умудрился шаблон сломать  да еще
#   --> The message was set сегодня какой то нехороший день у меня     телефон наушники не опознает  у блога как то умудрился шаблон сломать  да еще
#   --> Escaping single symbol words: сегодня какой то нехороший день меня телефон наушники не опознает блога как то умудрился шаблон сломать да еще сегодня какой то нехороший день у меня     телефон наушники не опознает  у блога как то умудрился шаблон сломать  да еще
#   --> The message was set сегодня какой то нехороший день меня телефон наушники не опознает блога как то умудрился шаблон сломать да еще
#   --> custom tokenizer was completed: ['день', 'телефон', 'наушник', 'опознать', 'блог', 'умудриться', 'шаблон', 'сломать']
#   --> The message was set думаю,на моем веку почта россии не поднимется со дна (((
#   --> The @word was removed думаю,на моем веку почта россии не поднимется со дна ((( думаю,на моем веку почта россии не поднимется со дна (((
#   --> The message was set думаю,на моем веку почта россии не поднимется со дна (((
#   --> Removing punctuation: думаю на моем веку почта россии не поднимется со дна     думаю,на моем веку почта россии не поднимется со дна (((
#   --> The message was set думаю на моем веку почта россии не поднимется со дна
#   --> Making to lower case: думаю на моем веку почта россии не поднимется со дна     думаю на моем веку почта россии не поднимется со дна
#   --> The message was set думаю на моем веку почта россии не поднимется со дна
#   --> Escaping single symbol words: думаю на моем веку почта россии не поднимется со дна думаю на моем веку почта россии не поднимется со дна
#   --> The message was set думаю на моем веку почта россии не поднимется со дна
#   --> custom tokenizer was completed: ['думать', 'век', 'почта', 'россия', 'подняться', 'дно']
#   --> The message was set Мне одному   напоминает дом-2? Путин делает реалити-шоу? O_o
#   --> The @word was removed Мне одному   напоминает дом-2? Путин делает реалити-шоу? O_o Мне одному   напоминает дом-2? Путин делает реалити-шоу? O_o
#   --> The message was set Мне одному   напоминает дом-2? Путин делает реалити-шоу? O_o
#   --> Removing punctuation: Мне одному   напоминает дом 2  Путин делает реалити шоу  O_o Мне одному   напоминает дом-2? Путин делает реалити-шоу? O_o
#   --> The message was set Мне одному   напоминает дом 2  Путин делает реалити шоу  O_o
#   --> Making to lower case: мне одному   напоминает дом 2  путин делает реалити шоу  o_o Мне одному   напоминает дом 2  Путин делает реалити шоу  O_o
#   --> The message was set мне одному   напоминает дом 2  путин делает реалити шоу  o_o
#   --> Escaping single symbol words: мне одному напоминает дом путин делает реалити шоу o_o мне одному   напоминает дом 2  путин делает реалити шоу  o_o
#   --> The message was set мне одному напоминает дом путин делает реалити шоу o_o
#   --> custom tokenizer was completed: ['напоминать', 'дом', 'путина', 'делать', 'шоу']
#   --> The message was set ебааааа сейчас модуль будет по региональной экономике ((
#   --> The @word was removed ебааааа сейчас модуль будет по региональной экономике (( ебааааа сейчас модуль будет по региональной экономике ((
#   --> The message was set ебааааа сейчас модуль будет по региональной экономике ((
#   --> Removing punctuation: ебааааа сейчас модуль будет по региональной экономике    ебааааа сейчас модуль будет по региональной экономике ((
#   --> The message was set ебааааа сейчас модуль будет по региональной экономике
#   --> Making to lower case: ебааааа сейчас модуль будет по региональной экономике    ебааааа сейчас модуль будет по региональной экономике
#   --> The message was set ебааааа сейчас модуль будет по региональной экономике
#   --> Escaping single symbol words: ебааааа сейчас модуль будет по региональной экономике ебааааа сейчас модуль будет по региональной экономике
#   --> The message was set ебааааа сейчас модуль будет по региональной экономике
#   --> custom tokenizer was completed: ['ебааааа', 'модуль', 'экономика']
#   --> The message was set @kordalona_mars оооууу ты меня анфолловил чувак((
#   --> The @word was removed   оооууу ты меня анфолловил чувак(( @kordalona_mars оооууу ты меня анфолловил чувак((
#   --> The message was set   оооууу ты меня анфолловил чувак((
#   --> Removing punctuation:   оооууу ты меня анфолловил чувак     оооууу ты меня анфолловил чувак((
#   --> The message was set   оооууу ты меня анфолловил чувак
#   --> Making to lower case:   оооууу ты меня анфолловил чувак     оооууу ты меня анфолловил чувак
#   --> The message was set   оооууу ты меня анфолловил чувак
#   --> Escaping single symbol words: оооууу ты меня анфолловил чувак   оооууу ты меня анфолловил чувак
#   --> The message was set оооууу ты меня анфолловил чувак
#   --> custom tokenizer was completed: ['оооууа', 'чувак']
#   --> The message was set вот так я встречаю зиму:(( http://t.co/FjivXAGcR9
#   --> The @word was removed вот так я встречаю зиму:(( http://t.co/FjivXAGcR9 вот так я встречаю зиму:(( http://t.co/FjivXAGcR9
#   --> The message was set вот так я встречаю зиму:(( http://t.co/FjivXAGcR9
#   --> Removing punctuation: вот так я встречаю зиму    http   t co FjivXAGcR9 вот так я встречаю зиму:(( http://t.co/FjivXAGcR9
#   --> The message was set вот так я встречаю зиму    http   t co FjivXAGcR9
#   --> Making to lower case: вот так я встречаю зиму    http   t co fjivxagcr9 вот так я встречаю зиму    http   t co FjivXAGcR9
#   --> The message was set вот так я встречаю зиму    http   t co fjivxagcr9
#   --> Escaping single symbol words: вот так встречаю зиму http co fjivxagcr9 вот так я встречаю зиму    http   t co fjivxagcr9
#   --> The message was set вот так встречаю зиму http co fjivxagcr9
#   --> custom tokenizer was completed: ['встречать', 'зима']
#   --> The message was set @Kyo_oppa ну вот, туда медведь прикреплялся.
#   --> The @word was removed   ну вот, туда медведь прикреплялся. @Kyo_oppa ну вот, туда медведь прикреплялся.
#   --> The message was set   ну вот, туда медведь прикреплялся.
#   --> Removing punctuation:   ну вот  туда медведь прикреплялся    ну вот, туда медведь прикреплялся.
#   --> The message was set   ну вот  туда медведь прикреплялся
#   --> Making to lower case:   ну вот  туда медведь прикреплялся    ну вот  туда медведь прикреплялся
#   --> The message was set   ну вот  туда медведь прикреплялся
#   --> Escaping single symbol words: ну вот туда медведь прикреплялся   ну вот  туда медведь прикреплялся
#   --> The message was set ну вот туда медведь прикреплялся
#   --> custom tokenizer was completed: ['медведь', 'прикрепляться']
#   --> The message was set чорт... хотела сходить в кино...  придется любоваться фильмом в уг качестве на компе(
#   --> The @word was removed чорт... хотела сходить в кино...  придется любоваться фильмом в уг качестве на компе( чорт... хотела сходить в кино...  придется любоваться фильмом в уг качестве на компе(
#   --> The message was set чорт... хотела сходить в кино...  придется любоваться фильмом в уг качестве на компе(
#   --> Removing punctuation: чорт    хотела сходить в кино     придется любоваться фильмом в уг качестве на компе  чорт... хотела сходить в кино...  придется любоваться фильмом в уг качестве на компе(
#   --> The message was set чорт    хотела сходить в кино     придется любоваться фильмом в уг качестве на компе
#   --> Making to lower case: чорт    хотела сходить в кино     придется любоваться фильмом в уг качестве на компе  чорт    хотела сходить в кино     придется любоваться фильмом в уг качестве на компе
#   --> The message was set чорт    хотела сходить в кино     придется любоваться фильмом в уг качестве на компе
#   --> Escaping single symbol words: чорт хотела сходить кино придется любоваться фильмом уг качестве на компе чорт    хотела сходить в кино     придется любоваться фильмом в уг качестве на компе
#   --> The message was set чорт хотела сходить кино придется любоваться фильмом уг качестве на компе
#   --> custom tokenizer was completed: ['чорт', 'хотеть', 'сходить', 'кино', 'прийтись', 'любоваться', 'фильм', 'качество', 'комп']
#   --> The message was set RT @arinaaaaonskul: Так плохо я себя не чувствовала давно :(
#   --> The @word was removed RT  : Так плохо я себя не чувствовала давно :(  RT @arinaaaaonskul: Так плохо я себя не чувствовала давно :(
#   --> The message was set RT  : Так плохо я себя не чувствовала давно :(
#   --> Removing punctuation: RT    Так плохо я себя не чувствовала давно     RT  : Так плохо я себя не чувствовала давно :(
#   --> The message was set RT    Так плохо я себя не чувствовала давно
#   --> Making to lower case: rt    так плохо я себя не чувствовала давно     RT    Так плохо я себя не чувствовала давно
#   --> The message was set rt    так плохо я себя не чувствовала давно
#   --> Escaping single symbol words: rt так плохо себя не чувствовала давно rt    так плохо я себя не чувствовала давно
#   --> The message was set rt так плохо себя не чувствовала давно
#   --> custom tokenizer was completed: ['чувствовать']
#   --> The message was set Как понизить температуру ноута? Снаружи +30, так что он постоянно раскалённый :(
#   --> The @word was removed Как понизить температуру ноута? Снаружи +30, так что он постоянно раскалённый :( Как понизить температуру ноута? Снаружи +30, так что он постоянно раскалённый :(
#   --> The message was set Как понизить температуру ноута? Снаружи +30, так что он постоянно раскалённый :(
#   --> Removing punctuation: Как понизить температуру ноута  Снаружи  30  так что он постоянно раскалённый    Как понизить температуру ноута? Снаружи +30, так что он постоянно раскалённый :(
#   --> The message was set Как понизить температуру ноута  Снаружи  30  так что он постоянно раскалённый
#   --> Making to lower case: как понизить температуру ноута  снаружи  30  так что он постоянно раскалённый    Как понизить температуру ноута  Снаружи  30  так что он постоянно раскалённый
#   --> The message was set как понизить температуру ноута  снаружи  30  так что он постоянно раскалённый
#   --> Escaping single symbol words: как понизить температуру ноута снаружи 30 так что он постоянно раскалённый как понизить температуру ноута  снаружи  30  так что он постоянно раскалённый
#   --> The message was set как понизить температуру ноута снаружи 30 так что он постоянно раскалённый
#   --> custom tokenizer was completed: ['понизить', 'температура', 'ноут', 'раскалить']
#   --> The message was set @Anastasia_pain думаешь упаду со стула? :(
#   --> The @word was removed   думаешь упаду со стула? :( @Anastasia_pain думаешь упаду со стула? :(
#   --> The message was set   думаешь упаду со стула? :(
#   --> Removing punctuation:   думаешь упаду со стула       думаешь упаду со стула? :(
#   --> The message was set   думаешь упаду со стула
#   --> Making to lower case:   думаешь упаду со стула       думаешь упаду со стула
#   --> The message was set   думаешь упаду со стула
#   --> Escaping single symbol words: думаешь упаду со стула   думаешь упаду со стула
#   --> The message was set думаешь упаду со стула
#   --> custom tokenizer was completed: ['думать', 'упасть', 'стул']
#   --> The message was set @Deniska_perm да нет, но условия будут более спартанские :(
#   --> The @word was removed   да нет, но условия будут более спартанские :( @Deniska_perm да нет, но условия будут более спартанские :(
#   --> The message was set   да нет, но условия будут более спартанские :(
#   --> Removing punctuation:   да нет  но условия будут более спартанские      да нет, но условия будут более спартанские :(
#   --> The message was set   да нет  но условия будут более спартанские
#   --> Making to lower case:   да нет  но условия будут более спартанские      да нет  но условия будут более спартанские
#   --> The message was set   да нет  но условия будут более спартанские
#   --> Escaping single symbol words: да нет но условия будут более спартанские   да нет  но условия будут более спартанские
#   --> The message was set да нет но условия будут более спартанские
#   --> custom tokenizer was completed: ['нет', 'условие']
#   --> The message was set Хотела маме сделать сюрприз, как всегда все навернулось(
#   --> The @word was removed Хотела маме сделать сюрприз, как всегда все навернулось( Хотела маме сделать сюрприз, как всегда все навернулось(
#   --> The message was set Хотела маме сделать сюрприз, как всегда все навернулось(
#   --> Removing punctuation: Хотела маме сделать сюрприз  как всегда все навернулось  Хотела маме сделать сюрприз, как всегда все навернулось(
#   --> The message was set Хотела маме сделать сюрприз  как всегда все навернулось
#   --> Making to lower case: хотела маме сделать сюрприз  как всегда все навернулось  Хотела маме сделать сюрприз  как всегда все навернулось
#   --> The message was set хотела маме сделать сюрприз  как всегда все навернулось
#   --> Escaping single symbol words: хотела маме сделать сюрприз как всегда все навернулось хотела маме сделать сюрприз  как всегда все навернулось
#   --> The message was set хотела маме сделать сюрприз как всегда все навернулось
#   --> custom tokenizer was completed: ['хотеть', 'мама', 'сделать', 'сюрприз', 'навернулось']
#   --> The message was set я блин сутками его жду а он с друзьями общаться! с которыми ежедневно видится! :(
#   --> The @word was removed я блин сутками его жду а он с друзьями общаться! с которыми ежедневно видится! :( я блин сутками его жду а он с друзьями общаться! с которыми ежедневно видится! :(
#   --> The message was set я блин сутками его жду а он с друзьями общаться! с которыми ежедневно видится! :(
#   --> Removing punctuation: я блин сутками его жду а он с друзьями общаться  с которыми ежедневно видится     я блин сутками его жду а он с друзьями общаться! с которыми ежедневно видится! :(
#   --> The message was set я блин сутками его жду а он с друзьями общаться  с которыми ежедневно видится
#   --> Making to lower case: я блин сутками его жду а он с друзьями общаться  с которыми ежедневно видится     я блин сутками его жду а он с друзьями общаться  с которыми ежедневно видится
#   --> The message was set я блин сутками его жду а он с друзьями общаться  с которыми ежедневно видится
#   --> Escaping single symbol words: блин сутками его жду он друзьями общаться которыми ежедневно видится я блин сутками его жду а он с друзьями общаться  с которыми ежедневно видится
#   --> The message was set блин сутками его жду он друзьями общаться которыми ежедневно видится
#   --> custom tokenizer was completed: ['блин', 'сутки', 'ждать', 'друг', 'общаться', 'видеться']
#   --> The message was set @Annya_Nik @YankaMurygina Так и думал:(
# Не судьба походу попасть к мастерам
#   --> The @word was removed     Так и думал:(
# Не судьба походу попасть к мастерам @Annya_Nik @YankaMurygina Так и думал:(
# Не судьба походу попасть к мастерам
#   --> The message was set     Так и думал:(
# Не судьба походу попасть к мастерам
#   --> Removing punctuation:     Так и думал
# Не судьба походу попасть к мастерам     Так и думал:(
# Не судьба походу попасть к мастерам
#   --> The message was set     Так и думал
# Не судьба походу попасть к мастерам
#   --> Making to lower case:     так и думал
# не судьба походу попасть к мастерам     Так и думал
# Не судьба походу попасть к мастерам
#   --> The message was set     так и думал
# не судьба походу попасть к мастерам
#   --> Escaping single symbol words: так думал не судьба походу попасть мастерам     так и думал
# не судьба походу попасть к мастерам
#   --> The message was set так думал не судьба походу попасть мастерам
#   --> custom tokenizer was completed: ['думать', 'судьба', 'поход', 'попасть', 'мастер']
#   --> The message was set RT @davidmsk: У берегов Коста-Рики водятся 1600 видов рыб. А на берег выходят черепахи весом до 500 кг. Но я не видел :( http://t.co/9ixMBH…
#   --> The @word was removed RT  : У берегов Коста-Рики водятся 1600 видов рыб. А на берег выходят черепахи весом до 500 кг. Но я не видел :( http://t.co/9ixMBH… RT @davidmsk: У берегов Коста-Рики водятся 1600 видов рыб. А на берег выходят черепахи весом до 500 кг. Но я не видел :( http://t.co/9ixMBH…
#   --> The message was set RT  : У берегов Коста-Рики водятся 1600 видов рыб. А на берег выходят черепахи весом до 500 кг. Но я не видел :( http://t.co/9ixMBH…
#   --> Removing punctuation: RT    У берегов Коста Рики водятся 1600 видов рыб  А на берег выходят черепахи весом до 500 кг  Но я не видел    http   t co 9ixMBH  RT  : У берегов Коста-Рики водятся 1600 видов рыб. А на берег выходят черепахи весом до 500 кг. Но я не видел :( http://t.co/9ixMBH…
#   --> The message was set RT    У берегов Коста Рики водятся 1600 видов рыб  А на берег выходят черепахи весом до 500 кг  Но я не видел    http   t co 9ixMBH
#   --> Making to lower case: rt    у берегов коста рики водятся 1600 видов рыб  а на берег выходят черепахи весом до 500 кг  но я не видел    http   t co 9ixmbh  RT    У берегов Коста Рики водятся 1600 видов рыб  А на берег выходят черепахи весом до 500 кг  Но я не видел    http   t co 9ixMBH
#   --> The message was set rt    у берегов коста рики водятся 1600 видов рыб  а на берег выходят черепахи весом до 500 кг  но я не видел    http   t co 9ixmbh
#   --> Escaping single symbol words: rt берегов коста рики водятся 1600 видов рыб на берег выходят черепахи весом до 500 кг но не видел http co 9ixmbh rt    у берегов коста рики водятся 1600 видов рыб  а на берег выходят черепахи весом до 500 кг  но я не видел    http   t co 9ixmbh
#   --> The message was set rt берегов коста рики водятся 1600 видов рыб на берег выходят черепахи весом до 500 кг но не видел http co 9ixmbh
#   --> custom tokenizer was completed: ['берег', 'водиться', 'вид', 'рыба', 'берег', 'выходить', 'черепаха', 'вес', 'видеть']
#   --> The message was set "@lisi_Ca: @maybe_reg49_27 @One_ENCLAVE @LyudaLa самая смешная из лисичек - тибетская. Это не фотошоп http://t.co/kDDYZartwl" о_О
#   --> The @word was removed " :       самая смешная из лисичек - тибетская. Это не фотошоп http://t.co/kDDYZartwl" о_О "@lisi_Ca: @maybe_reg49_27 @One_ENCLAVE @LyudaLa самая смешная из лисичек - тибетская. Это не фотошоп http://t.co/kDDYZartwl" о_О
#   --> The message was set " :       самая смешная из лисичек - тибетская. Это не фотошоп http://t.co/kDDYZartwl" о_О
#   --> Removing punctuation:           самая смешная из лисичек   тибетская  Это не фотошоп http   t co kDDYZartwl  о_О " :       самая смешная из лисичек - тибетская. Это не фотошоп http://t.co/kDDYZartwl" о_О
#   --> The message was set           самая смешная из лисичек   тибетская  Это не фотошоп http   t co kDDYZartwl  о_О
#   --> Making to lower case:           самая смешная из лисичек   тибетская  это не фотошоп http   t co kddyzartwl  о_о           самая смешная из лисичек   тибетская  Это не фотошоп http   t co kDDYZartwl  о_О
#   --> The message was set           самая смешная из лисичек   тибетская  это не фотошоп http   t co kddyzartwl  о_о
#   --> Escaping single symbol words: самая смешная из лисичек тибетская это не фотошоп http co kddyzartwl о_о           самая смешная из лисичек   тибетская  это не фотошоп http   t co kddyzartwl  о_о
#   --> The message was set самая смешная из лисичек тибетская это не фотошоп http co kddyzartwl о_о
#   --> custom tokenizer was completed: ['тибетский', 'фотошоп']
#   --> The message was set Потеряла креапления от борда. Как так! Я же их не снимала(
#   --> The @word was removed Потеряла креапления от борда. Как так! Я же их не снимала( Потеряла креапления от борда. Как так! Я же их не снимала(
#   --> The message was set Потеряла креапления от борда. Как так! Я же их не снимала(
#   --> Removing punctuation: Потеряла креапления от борда  Как так  Я же их не снимала  Потеряла креапления от борда. Как так! Я же их не снимала(
#   --> The message was set Потеряла креапления от борда  Как так  Я же их не снимала
#   --> Making to lower case: потеряла креапления от борда  как так  я же их не снимала  Потеряла креапления от борда  Как так  Я же их не снимала
#   --> The message was set потеряла креапления от борда  как так  я же их не снимала
#   --> Escaping single symbol words: потеряла креапления от борда как так же их не снимала потеряла креапления от борда  как так  я же их не снимала
#   --> The message was set потеряла креапления от борда как так же их не снимала
#   --> custom tokenizer was completed: ['потерять', 'креапление', 'борд', 'снимать']
#   --> The message was set RT @Ksenyamalischev: Устала от семинара;(
#   --> The @word was removed RT  : Устала от семинара;( RT @Ksenyamalischev: Устала от семинара;(
#   --> The message was set RT  : Устала от семинара;(
#   --> Removing punctuation: RT    Устала от семинара   RT  : Устала от семинара;(
#   --> The message was set RT    Устала от семинара
#   --> Making to lower case: rt    устала от семинара   RT    Устала от семинара
#   --> The message was set rt    устала от семинара
#   --> Escaping single symbol words: rt устала от семинара rt    устала от семинара
#   --> The message was set rt устала от семинара
#   --> custom tokenizer was completed: ['устать', 'семинар']
#   --> The message was set Опять простыла....!!!;(Все гуляют,катают,тусуют,а я!;(((Что за невезение!!!
#   --> The @word was removed Опять простыла....!!!;(Все гуляют,катают,тусуют,а я!;(((Что за невезение!!! Опять простыла....!!!;(Все гуляют,катают,тусуют,а я!;(((Что за невезение!!!
#   --> The message was set Опять простыла....!!!;(Все гуляют,катают,тусуют,а я!;(((Что за невезение!!!
#   --> Removing punctuation: Опять простыла         Все гуляют катают тусуют а я     Что за невезение    Опять простыла....!!!;(Все гуляют,катают,тусуют,а я!;(((Что за невезение!!!
#   --> The message was set Опять простыла         Все гуляют катают тусуют а я     Что за невезение
#   --> Making to lower case: опять простыла         все гуляют катают тусуют а я     что за невезение    Опять простыла         Все гуляют катают тусуют а я     Что за невезение
#   --> The message was set опять простыла         все гуляют катают тусуют а я     что за невезение
# ...
#   --> The message was set пооч я не программист    пж сделайте кто нибудь мне ноут
#   --> Making to lower case: пооч я не программист    пж сделайте кто нибудь мне ноут          пооч я не программист    пж сделайте кто нибудь мне ноут
#   --> The message was set пооч я не программист    пж сделайте кто нибудь мне ноут
#   --> Escaping single symbol words: пооч не программист пж сделайте кто нибудь мне ноут пооч я не программист    пж сделайте кто нибудь мне ноут
#   --> The message was set пооч не программист пж сделайте кто нибудь мне ноут
#   --> custom tokenizer was completed: ['пооч', 'программист', 'сделать', 'ноут']
#   --> The message was set RT @tasagufuxuw: Скажите, что Arakawa Under the Bridge — это не бред! Я его боюсь смотреть. =(
#   --> The @word was removed RT  : Скажите, что Arakawa Under the Bridge — это не бред! Я его боюсь смотреть. =( RT @tasagufuxuw: Скажите, что Arakawa Under the Bridge — это не бред! Я его боюсь смотреть. =(
#   --> The message was set RT  : Скажите, что Arakawa Under the Bridge — это не бред! Я его боюсь смотреть. =(
#   --> Removing punctuation: RT    Скажите  что Arakawa Under the Bridge   это не бред  Я его боюсь смотреть     RT  : Скажите, что Arakawa Under the Bridge — это не бред! Я его боюсь смотреть. =(
#   --> The message was set RT    Скажите  что Arakawa Under the Bridge   это не бред  Я его боюсь смотреть
#   --> Making to lower case: rt    скажите  что arakawa under the bridge   это не бред  я его боюсь смотреть     RT    Скажите  что Arakawa Under the Bridge   это не бред  Я его боюсь смотреть
#   --> The message was set rt    скажите  что arakawa under the bridge   это не бред  я его боюсь смотреть
#   --> Escaping single symbol words: rt скажите что arakawa under the bridge это не бред его боюсь смотреть rt    скажите  что arakawa under the bridge   это не бред  я его боюсь смотреть
#   --> The message was set rt скажите что arakawa under the bridge это не бред его боюсь смотреть
#   --> custom tokenizer was completed: ['сказать', 'бред', 'бояться', 'смотреть']
#   --> The message was set @Marilinka да ужасно всё(у нас теперь всё по баллам. все зачеты и промежуточные аттестации влияют на стипендию((
#   --> The @word was removed   да ужасно всё(у нас теперь всё по баллам. все зачеты и промежуточные аттестации влияют на стипендию(( @Marilinka да ужасно всё(у нас теперь всё по баллам. все зачеты и промежуточные аттестации влияют на стипендию((
#   --> The message was set   да ужасно всё(у нас теперь всё по баллам. все зачеты и промежуточные аттестации влияют на стипендию((
#   --> Removing punctuation:   да ужасно всё у нас теперь всё по баллам  все зачеты и промежуточные аттестации влияют на стипендию     да ужасно всё(у нас теперь всё по баллам. все зачеты и промежуточные аттестации влияют на стипендию((
#   --> The message was set   да ужасно всё у нас теперь всё по баллам  все зачеты и промежуточные аттестации влияют на стипендию
#   --> Making to lower case:   да ужасно всё у нас теперь всё по баллам  все зачеты и промежуточные аттестации влияют на стипендию     да ужасно всё у нас теперь всё по баллам  все зачеты и промежуточные аттестации влияют на стипендию
#   --> The message was set   да ужасно всё у нас теперь всё по баллам  все зачеты и промежуточные аттестации влияют на стипендию
#   --> Escaping single symbol words: да ужасно всё нас теперь всё по баллам все зачеты промежуточные аттестации влияют на стипендию   да ужасно всё у нас теперь всё по баллам  все зачеты и промежуточные аттестации влияют на стипендию
#   --> The message was set да ужасно всё нас теперь всё по баллам все зачеты промежуточные аттестации влияют на стипендию
#   --> custom tokenizer was completed: ['балл', 'зачет', 'аттестация', 'влиять', 'стипендия']
#   --> The message was set У меня сегодня в школе отжали часы и не отдаю!!! Я по ним очень сучаю((( верните их мне
#   --> The @word was removed У меня сегодня в школе отжали часы и не отдаю!!! Я по ним очень сучаю((( верните их мне У меня сегодня в школе отжали часы и не отдаю!!! Я по ним очень сучаю((( верните их мне
#   --> The message was set У меня сегодня в школе отжали часы и не отдаю!!! Я по ним очень сучаю((( верните их мне
#   --> Removing punctuation: У меня сегодня в школе отжали часы и не отдаю    Я по ним очень сучаю    верните их мне У меня сегодня в школе отжали часы и не отдаю!!! Я по ним очень сучаю((( верните их мне
#   --> The message was set У меня сегодня в школе отжали часы и не отдаю    Я по ним очень сучаю    верните их мне
#   --> Making to lower case: у меня сегодня в школе отжали часы и не отдаю    я по ним очень сучаю    верните их мне У меня сегодня в школе отжали часы и не отдаю    Я по ним очень сучаю    верните их мне
#   --> The message was set у меня сегодня в школе отжали часы и не отдаю    я по ним очень сучаю    верните их мне
#   --> Escaping single symbol words: меня сегодня школе отжали часы не отдаю по ним очень сучаю верните их мне у меня сегодня в школе отжали часы и не отдаю    я по ним очень сучаю    верните их мне
#   --> The message was set меня сегодня школе отжали часы не отдаю по ним очень сучаю верните их мне
#   --> custom tokenizer was completed: ['школа', 'отжать', 'час', 'отдавать', 'сучаять', 'вернуть']
#   --> The message was set что-то я забросила свой тамблер(
# надо засрать ленту:3
#   --> The @word was removed что-то я забросила свой тамблер(
# надо засрать ленту:3 что-то я забросила свой тамблер(
# надо засрать ленту:3
#   --> The message was set что-то я забросила свой тамблер(
# надо засрать ленту:3
#   --> Removing punctuation: что то я забросила свой тамблер
# надо засрать ленту 3 что-то я забросила свой тамблер(
# надо засрать ленту:3
#   --> The message was set что то я забросила свой тамблер
# надо засрать ленту 3
#   --> Making to lower case: что то я забросила свой тамблер
# надо засрать ленту 3 что то я забросила свой тамблер
# надо засрать ленту 3
#   --> The message was set что то я забросила свой тамблер
# надо засрать ленту 3
#   --> Escaping single symbol words: что то забросила свой тамблер надо засрать ленту что то я забросила свой тамблер
# надо засрать ленту 3
#   --> The message was set что то забросила свой тамблер надо засрать ленту
#   --> custom tokenizer was completed: ['забросить', 'тамблер', 'засрать', 'лента']
#   --> The message was set RT @Nkllapa: Мдааа большинство просто забыли или не знали :(((
#   --> The @word was removed RT  : Мдааа большинство просто забыли или не знали :((( RT @Nkllapa: Мдааа большинство просто забыли или не знали :(((
#   --> The message was set RT  : Мдааа большинство просто забыли или не знали :(((
#   --> Removing punctuation: RT    Мдааа большинство просто забыли или не знали      RT  : Мдааа большинство просто забыли или не знали :(((
#   --> The message was set RT    Мдааа большинство просто забыли или не знали
#   --> Making to lower case: rt    мдааа большинство просто забыли или не знали      RT    Мдааа большинство просто забыли или не знали
#   --> The message was set rt    мдааа большинство просто забыли или не знали
#   --> Escaping single symbol words: rt мдааа большинство просто забыли или не знали rt    мдааа большинство просто забыли или не знали
#   --> The message was set rt мдааа большинство просто забыли или не знали
#   --> custom tokenizer was completed: ['мдааа', 'большинство', 'забыть', 'знать']
#   --> The message was set @alenasheyanova Не помню, чтобы я в прошлый раз болела :(
#   --> The @word was removed   Не помню, чтобы я в прошлый раз болела :( @alenasheyanova Не помню, чтобы я в прошлый раз болела :(
#   --> The message was set   Не помню, чтобы я в прошлый раз болела :(
#   --> Removing punctuation:   Не помню  чтобы я в прошлый раз болела      Не помню, чтобы я в прошлый раз болела :(
#   --> The message was set   Не помню  чтобы я в прошлый раз болела
#   --> Making to lower case:   не помню  чтобы я в прошлый раз болела      Не помню  чтобы я в прошлый раз болела
#   --> The message was set   не помню  чтобы я в прошлый раз болела
#   --> Escaping single symbol words: не помню чтобы прошлый раз болела   не помню  чтобы я в прошлый раз болела
#   --> The message was set не помню чтобы прошлый раз болела
#   --> custom tokenizer was completed: ['помнить', 'раз', 'болеть']
#   --> The message was set мой твиттер тупит :(
#  #mtvstars Justin Bieber
#   --> The @word was removed мой твиттер тупит :(
#  #mtvstars Justin Bieber мой твиттер тупит :(
#  #mtvstars Justin Bieber
#   --> The message was set мой твиттер тупит :(
#  #mtvstars Justin Bieber
#   --> Removing punctuation: мой твиттер тупит
#   mtvstars Justin Bieber мой твиттер тупит :(
#  #mtvstars Justin Bieber
#   --> The message was set мой твиттер тупит
#   mtvstars Justin Bieber
#   --> Making to lower case: мой твиттер тупит
#   mtvstars justin bieber мой твиттер тупит
#   mtvstars Justin Bieber
#   --> The message was set мой твиттер тупит
#   mtvstars justin bieber
#   --> Escaping single symbol words: мой твиттер тупит mtvstars justin bieber мой твиттер тупит
#   mtvstars justin bieber
#   --> The message was set мой твиттер тупит mtvstars justin bieber
#   --> custom tokenizer was completed: ['твиттер', 'тупить']
#   --> The message was set RT @16believe19: @HORAN_NlALL @graciemitchie блин, а я только обрадовалась что он не умер :((
#   --> The @word was removed RT  :     блин, а я только обрадовалась что он не умер :(( RT @16believe19: @HORAN_NlALL @graciemitchie блин, а я только обрадовалась что он не умер :((
#   --> The message was set RT  :     блин, а я только обрадовалась что он не умер :((
#   --> Removing punctuation: RT        блин  а я только обрадовалась что он не умер     RT  :     блин, а я только обрадовалась что он не умер :((
#   --> The message was set RT        блин  а я только обрадовалась что он не умер
#   --> Making to lower case: rt        блин  а я только обрадовалась что он не умер     RT        блин  а я только обрадовалась что он не умер
#   --> The message was set rt        блин  а я только обрадовалась что он не умер
#   --> Escaping single symbol words: rt блин только обрадовалась что он не умер rt        блин  а я только обрадовалась что он не умер
#   --> The message was set rt блин только обрадовалась что он не умер
#   --> custom tokenizer was completed: ['обрадоваться', 'умереть']
#   --> The message was set Никогда не любила всякие реалити, но Американский жених просто нечто, сегодня последняя серия(
#   --> The @word was removed Никогда не любила всякие реалити, но Американский жених просто нечто, сегодня последняя серия( Никогда не любила всякие реалити, но Американский жених просто нечто, сегодня последняя серия(
#   --> The message was set Никогда не любила всякие реалити, но Американский жених просто нечто, сегодня последняя серия(
#   --> Removing punctuation: Никогда не любила всякие реалити  но Американский жених просто нечто  сегодня последняя серия  Никогда не любила всякие реалити, но Американский жених просто нечто, сегодня последняя серия(
#   --> The message was set Никогда не любила всякие реалити  но Американский жених просто нечто  сегодня последняя серия
#   --> Making to lower case: никогда не любила всякие реалити  но американский жених просто нечто  сегодня последняя серия  Никогда не любила всякие реалити  но Американский жених просто нечто  сегодня последняя серия
#   --> The message was set никогда не любила всякие реалити  но американский жених просто нечто  сегодня последняя серия
#   --> Escaping single symbol words: никогда не любила всякие реалити но американский жених просто нечто сегодня последняя серия никогда не любила всякие реалити  но американский жених просто нечто  сегодня последняя серия
#   --> The message was set никогда не любила всякие реалити но американский жених просто нечто сегодня последняя серия
#   --> custom tokenizer was completed: ['любить', 'реалить', 'жених', 'серия']
#   --> The message was set @vete_al_diablo полное наебалово, в "Связном" нельзя ойфон или PS4 купить со скидкой=(
#   --> The @word was removed   полное наебалово, в "Связном" нельзя ойфон или PS4 купить со скидкой=( @vete_al_diablo полное наебалово, в "Связном" нельзя ойфон или PS4 купить со скидкой=(
#   --> The message was set   полное наебалово, в "Связном" нельзя ойфон или PS4 купить со скидкой=(
#   --> Removing punctuation:   полное наебалово  в  Связном  нельзя ойфон или PS4 купить со скидкой     полное наебалово, в "Связном" нельзя ойфон или PS4 купить со скидкой=(
#   --> The message was set   полное наебалово  в  Связном  нельзя ойфон или PS4 купить со скидкой
#   --> Making to lower case:   полное наебалово  в  связном  нельзя ойфон или ps4 купить со скидкой     полное наебалово  в  Связном  нельзя ойфон или PS4 купить со скидкой
#   --> The message was set   полное наебалово  в  связном  нельзя ойфон или ps4 купить со скидкой
#   --> Escaping single symbol words: полное наебалово связном нельзя ойфон или ps4 купить со скидкой   полное наебалово  в  связном  нельзя ойфон или ps4 купить со скидкой
#   --> The message was set полное наебалово связном нельзя ойфон или ps4 купить со скидкой
#   --> custom tokenizer was completed: ['наебалово', 'связный', 'ойфон', 'купить', 'скидка']
#   --> The message was set Хотел посмотреть на symfony..теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О
#   --> The @word was removed Хотел посмотреть на symfony..теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О Хотел посмотреть на symfony..теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О
#   --> The message was set Хотел посмотреть на symfony..теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О
#   --> Removing punctuation: Хотел посмотреть на symfony  теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О Хотел посмотреть на symfony..теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О
#   --> The message was set Хотел посмотреть на symfony  теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О
#   --> Making to lower case: хотел посмотреть на symfony  теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_о Хотел посмотреть на symfony  теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_О
#   --> The message was set хотел посмотреть на symfony  теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_о
#   --> Escaping single symbol words: хотел посмотреть на symfony теперь сижу думаю какой профит symfony перед yii захрена мне ее учить о_о хотел посмотреть на symfony  теперь сижу и думаю какой профит у symfony перед yii и захрена мне ее учить о_о
#   --> The message was set хотел посмотреть на symfony теперь сижу думаю какой профит symfony перед yii захрена мне ее учить о_о
#   --> custom tokenizer was completed: ['хотеть', 'посмотреть', 'сидеть', 'думать', 'профит', 'захрен', 'учить']
#   --> The message was set Как таких красоток могли не пустить?:-( http://t.co/tVTxtXAPQM
#   --> The @word was removed Как таких красоток могли не пустить?:-( http://t.co/tVTxtXAPQM Как таких красоток могли не пустить?:-( http://t.co/tVTxtXAPQM
#   --> The message was set Как таких красоток могли не пустить?:-( http://t.co/tVTxtXAPQM
#   --> Removing punctuation: Как таких красоток могли не пустить     http   t co tVTxtXAPQM Как таких красоток могли не пустить?:-( http://t.co/tVTxtXAPQM
#   --> The message was set Как таких красоток могли не пустить     http   t co tVTxtXAPQM
#   --> Making to lower case: как таких красоток могли не пустить     http   t co tvtxtxapqm Как таких красоток могли не пустить     http   t co tVTxtXAPQM
#   --> The message was set как таких красоток могли не пустить     http   t co tvtxtxapqm
#   --> Escaping single symbol words: как таких красоток могли не пустить http co tvtxtxapqm как таких красоток могли не пустить     http   t co tvtxtxapqm
#   --> The message was set как таких красоток могли не пустить http co tvtxtxapqm
